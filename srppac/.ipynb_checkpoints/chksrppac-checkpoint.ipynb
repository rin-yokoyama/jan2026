# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark = SparkSession.builder.master("local[10]").getOrCreate()
spark.sparkContext.setLogLevel("ERROR")

df = spark.read.parquet("parquet/run0024_srppac.parquet")
df.show(5)
print(df.filter("charge2_x > 0 AND charge2_y > 0 AND ABS(id0_x - id1_x) = 1 AND ABS(id0_y - id1_y) = 1 AND ABS(id0_x - id2_x) = 1 AND ABS(id0_y - id2_y) = 1").count())
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/13 11:41:09 WARN Utils: Your hostname, gpuana02, resolves to a loopback address: 127.0.1.1; using 192.168.1.216 instead (on interface enp4s0)
# 26/01/13 11:41:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 26/01/13 11:41:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/13 11:41:10 WARN RapidsPluginUtils: RAPIDS Accelerator 25.10.0 using cudf 25.10.0, private revision 28e7c65b3c0526baba384d9b97ee12e4d6766d9a
# ...

# %%
from hist.sparkHist2d import Hist2DArrays
from hist.sparkHist2d import Hist2D
from hist.sparkHist1d import Hist1D
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

plt.figure(0, figsize=(12,4))
plt.rcParams["font.size"] = 8
plt.subplot2grid((1,2),(0,0))
h = Hist2D(df, ["timing0_x","charge0_x"], [200,200], [[-100, 0], [0, 100]], norm=LogNorm(), interpolation='none')
plt.subplot2grid((1,2),(0,1))
h = Hist2D(df, ["timing0_y","charge0_y"], [200,200], [[-100, 0], [0, 100]], norm=LogNorm(), interpolation='none')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 10
#       8 plt.rcParams["font.size"] = 8
#       9 plt.subplot2grid((1,2),(0,0))
# ---> 10 h = Hist2D(df, ["timing0_x","charge0_x"], [200,200], [[-100, 0], [0, 100]], norm=LogNorm(), interpolation='none')
#      11 plt.subplot2grid((1,2),(0,1))
#      12 h = Hist2D(df, ["timing0_y","charge0_y"], [200,200], [[-100, 0], [0, 100]], norm=LogNorm(), interpolation='none')
#
# File ~/opt/spark-oedo/hist/sparkHist2d.py:80, in Hist2D(dataFrame, colName, nbins, range, **kwargs)
#      77 plt.title("2D Histogram of " + colName[1] + " vs " + colName[0])
#      79 # Show the color bar
# ---> 80 plt.colorbar(label='Counts')
#      82 # Print statistics
#      83 print("Statistics:")
#
# File ~/opt/miniconda3/envs/spark-oedo/lib/python3.12/site-packages/matplotlib/pyplot.py:2533, in colorbar(mappable, cax, ax, **kwargs)
# ...

# %%
plt.figure(0, figsize=(12,4))
plt.rcParams["font.size"] = 8
plt.subplot2grid((1,2),(0,0))
h = Hist1D(df, "size_x", 33, [-0.5, 31.5])
plt.yscale('log')
plt.subplot2grid((1,2),(0,1))
h = Hist1D(df, "size_y", 33, [-0.5, 31.5])
plt.yscale('log')
plt.show()
# Out:
# Total entries: 169654, Underflow: 0, Inside: 169611, Overflow: 43
# Total entries: 169654, Underflow: 0, Inside: 169619, Overflow: 35

# %%
plt.figure(0, figsize=(12,4))
plt.rcParams["font.size"] = 8
plt.subplot2grid((1,2),(0,0))
h = Hist2D(df.filter("size_x<7"), ["timing0_x","charge0_x"], [200,200], [[-100, 0], [0, 100]], norm=LogNorm(), interpolation='none')
plt.subplot2grid((1,2),(0,1))
h = Hist2D(df.filter("size_y<7"), ["timing0_y","charge0_y"], [200,200], [[-100, 0], [0, 100]], norm=LogNorm(), interpolation='none')
plt.show()
# Out:
# Statistics:
# [[0.00000e+00 0.00000e+00 0.00000e+00]
#  [0.00000e+00 1.64016e+05 1.50000e+01]
#  [0.00000e+00 0.00000e+00 0.00000e+00]]
# Statistics:
# [[0.00000e+00 2.00000e+00 0.00000e+00]
#  [0.00000e+00 1.64215e+05 6.60000e+01]
#  [0.00000e+00 0.00000e+00 0.00000e+00]]

# %%
df_f = df.filter("size_x<7").filter("size_y<7")
plt.figure(0, figsize=(12,6))
plt.rcParams["font.size"] = 6
plt.subplot2grid((2,3),(0,0))
h = Hist2D(df_f, ["id0_x","charge0_x"], [33,200], [[-0.5, 31.5], [0, 80]], norm=LogNorm(), interpolation='none')
plt.subplot2grid((2,3),(0,1))
h = Hist2D(df_f, ["id1_x","charge1_x"], [33,200], [[-0.5, 31.5], [0, 80]], norm=LogNorm(), interpolation='none')
plt.subplot2grid((2,3),(0,2))
h = Hist2D(df_f, ["id2_x","charge2_x"], [33,200], [[-0.5, 31.5], [0, 80]], norm=LogNorm(), interpolation='none')
plt.subplot2grid((2,3),(1,0))
h = Hist2D(df_f, ["id0_y","charge0_y"], [33,200], [[-0.5, 31.5], [0, 80]], norm=LogNorm(), interpolation='none')
plt.subplot2grid((2,3),(1,1))
h = Hist2D(df_f, ["id1_y","charge1_y"], [33,200], [[-0.5, 31.5], [0, 80]], norm=LogNorm(), interpolation='none')
plt.subplot2grid((2,3),(1,2))
h = Hist2D(df_f, ["id2_y","charge2_y"], [33,200], [[-0.5, 31.5], [0, 80]], norm=LogNorm(), interpolation='none')
plt.show()
# Out:
# Statistics:
# [[     0.      0.      0.]
#  [     0. 163748.      0.]
#  [     0.      0.      0.]]
# Statistics:
# [[     0.      0.      0.]
#  [     0. 163738.      0.]
#  [     0.      0.      0.]]
# Statistics:
# [[     0.      0.      0.]
#  [     0. 163514.      0.]
#  [     0.      0.      0.]]
# Statistics:
# [[0.00000e+00 1.00000e+00 0.00000e+00]
#  [0.00000e+00 1.63747e+05 0.00000e+00]
#  [0.00000e+00 0.00000e+00 0.00000e+00]]
# Statistics:
# [[     0.      0.      0.]
#  [     0. 163699.      0.]
#  [     0.      0.      0.]]
# Statistics:
# [[     0.      0.      0.]
#  [     0. 161935.      0.]
#  [     0.      0.      0.]]
